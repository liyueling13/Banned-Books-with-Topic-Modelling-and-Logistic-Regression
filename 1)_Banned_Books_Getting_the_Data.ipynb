# %% [markdown]
# <a href="https://colab.research.google.com/github/liyueling13/Predicting-Banned-Books/blob/main/1)_Banned_Books_Getting_the_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PEN America Banned Books -- pulling descriptions and publication date
# 10/30/23

# %% [markdown]
# ## Setup

# %%
# this performs line wrapping on output text in Colab

from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Data Science/Springboard assignments/Capstone Three/Banned Books')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Load Pen America Banned Books

# %%
banned_df = pd.read_csv('PEN America Banned Books.csv', header=None)
columns = ['author', 'title']
banned_df.columns = columns
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 3         Acevedo, Elizabeth
# 4         Acevedo, Elizabeth
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   title
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# 2530  Black Enough: Stories of Being Young & Black i...
# 2531  Grandpa Cacao: A Tale of Chocolate, from Farm ...
#
# [2532 rows x 2 columns]

# %%
banned_df.drop_duplicates(inplace=True)
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 6              Aciman, André
# 7                Acito, Marc
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   title
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 6     Call Me By Your Name (Call Me By Your Name Ser...
# 7     How I Paid for College: A Novel of Sex, Theft,...
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# 2530  Black Enough: Stories of Being Young & Black i...
# 2531  Grandpa Cacao: A Tale of Chocolate, from Farm ...
#
# [1656 rows x 2 columns]

# %%
# remove trailing whitespaces
banned_df = banned_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Let's clean up the dataframe. Some of the titles include subtitles and descriptions. My API call won't work on these. I will remove subtitles/descriptions by dropping everything after a parentheses or colon.

# %%
banned_df['title'] = banned_df['title'].str.replace(r'[:\(\[].*$', '', regex=True)
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 6              Aciman, André   Call Me By Your Name
# 7                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 2527            Zia, Farhana  The Garden of My Imaan
# 2528         Ziemke, Kristin          Read the World
# 2529              Zoboi, Ibi         American Street
# 2530              Zoboi, Ibi            Black Enough
# 2531        Zunon, Elizabeth           Grandpa Cacao
#
# [1656 rows x 2 columns]

# %%
banned_df.drop_duplicates(inplace=True)
banned_df

# %% [markdown]
# ## Let's figure out how to query the Google Books API

# %%
# import requests

# Google Books API key
# API_KEY = redacted
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_book_json(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    print(data)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = "All Boys Aren't Blue"
# author = "Johnson, George M."
# get_book_json(title, author)

# %%
def get_book_details(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        if 'items' in data:
            book = data['items'][0]['volumeInfo']
            title = book.get('title', 'N/A')
            authors = ', '.join(book.get('authors', ['N/A']))
            description = book.get('description', 'N/A')
            published_date = book.get('publishedDate', 'N/A')
            print(f'Title: {title}')
            print(f'Authors: {authors}')
            print(f'Description: {description}')
            print(f'Published Date: {published_date}')
        else:
            print('Book not found.')
    else:
        print('Error fetching data from Google Books API.')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = "All Boys Aren't Blue"
# author = "Johnson, George M."
# get_book_details(title, author)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Title: All Boys Aren't Blue
# Authors: George M. Johnson
# Description: *An Amazon Best Book of the Year optioned for television by Gabrielle Union!* In a series of personal essays, prominent journalist and LGBTQIA+ activist George M. Johnson explores his childhood, adolescence, and college years in New Jersey and Virginia. From the memories of getting his teeth kicked out by bullies at age five, to flea marketing with his loving grandmother, to his first sexual relationships, this young-adult memoir weaves together the trials and triumphs faced by Black queer boys. Both a primer for teens eager to be allies as well as a reassuring testimony for young queer men of color, All Boys Aren't Blue covers topics such as gender identity, toxic masculinity, brotherhood, family, structural marginalization, consent, and Black joy. Johnson's emotionally frank style of writing will appeal directly to young adults.
# Published Date: 2020-04-28

# %% [markdown]
# ## Let's pull descriptions and publishing dates from the Google Books API

# %%
from numpy import NaN
banned_df['description'] = NaN
banned_df['published_date'] = NaN
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  description  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades          NaN
# 1         Acevedo, Elizabeth      Clap When You Land          NaN
# 2         Acevedo, Elizabeth              The Poet X          NaN
# 6              Aciman, André   Call Me By Your Name           NaN
# 7                Acito, Marc  How I Paid for College          NaN
# ...                      ...                     ...          ...
# 2527            Zia, Farhana  The Garden of My Imaan          NaN
# 2528         Ziemke, Kristin          Read the World          NaN
# 2529              Zoboi, Ibi         American Street          NaN
# 2530              Zoboi, Ibi            Black Enough          NaN
# 2531        Zunon, Elizabeth           Grandpa Cacao          NaN
#
#       published_date
# 0                NaN
# 1                NaN
# 2                NaN
# 6                NaN
# 7                NaN
# ...              ...
# 2527             NaN
# 2528             NaN
# 2529             NaN
# 2530             NaN
# 2531             NaN
#
# [1656 rows x 4 columns]

# %%
def paste_book_details(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        if 'items' in data:
            book = data['items'][0]['volumeInfo']
            title = book.get('title', 'N/A')
            authors = ', '.join(book.get('authors', ['N/A']))
            description = book.get('description', 'N/A')
            published_date = book.get('publishedDate', 'N/A')
            banned_df.loc[banned_df['title']==title, 'description'] = description
            banned_df.loc[banned_df['title']==title, 'published_date'] = published_date
        else:
            print(f'Title: {title} - Book not found.')
    else:
        print(f'Title: {title} - Error fetching data from Google Books API.')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = 'Clap When You Land'
# author = 'Acevedo, Elizabeth'
# paste_book_details(title, author)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# banned_df.loc[banned_df['title']==title]
# it works!
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                author               title  \
# 1  Acevedo, Elizabeth  Clap When You Land
#
#                                          description published_date
# 1  In a novel-in-verse that brims with grief and ...     2020-05-05

# %%
banned_df.iloc[0]['author']
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 'Àbíké-Íyímídé, Faridah'

# %% [markdown]
# Google API has quota limits. I'm limited to 1000 queries per day and 100 queries per min. So I will do this iteratively in 50s and wait a couple minutes between each query.

# %%
# df_len = len(banned_df)

# import time
# batch_size = 50

# for i in range(0, df_len, batch_size):
  #   for j in range(i, min(i+batch_size, total_items)):
    #   title = banned_df.iloc[j]['title']
    #   author = banned_df.iloc[j]['author']
    #   paste_book_details(title, author)
  #   time.sleep(60)

# %%
banned_df.head(50)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                         author  \
# 0       Àbíké-Íyímídé, Faridah
# 1           Acevedo, Elizabeth
# 2           Acevedo, Elizabeth
# 6                Aciman, André
# 7                  Acito, Marc
# 8               Ada, Alma Flor
# 9                 Addasi, Maha
# 10               Adeyemi, Tomi
# 11               Adeyoha, Koja
# 12   Adichie, Chimamanda Ngozi
# 13               Adler, Dahlia
# 14            Agell, Charlotte
# 15               Ahmadi, Arvin
# 17                 Ahmed, Roda
# 18               Ahmed, Samira
# 20              Ahmed, Sara K.
# 22           Albertalli, Becky
# 23           Albertalli, Becky
# 24           Albertalli, Becky
# 26           Albertalli, Becky
# 27           Albertalli, Becky
# 30           Albertalli, Becky
# 33           Albertalli, Becky
# 36              Aleman, Daniel
# 37            Alexander, Kwame
# 38         Alexander, Michelle
# 41             Alexie, Sherman
# 57             Alexie, Sherman
# 58             Alger, Cristina
# 59                Alko, Selina
# 60             Allende, Isabel
# 61        Alley, Kristy Dallas
# 62            Allison, Anthony
# 63         Allman, John Robert
# 64        Altman, Linda Jacobs
# 66       Amnesty International
# 67              Anaya, Rudolfo
# 68                  Ancrum, K.
# 69        Anders, Charlie Jane
# 70            Anderson, Airlie
# 71             Anderson, Carol
# 72      Anderson, Laurie Halse
# 75      Anderson, Laurie Halse
# 81             Anderson, M. T.
# 82               Andrews, Arin
# 83              Andrews, Jesse
# 97              Andrews, Jesse
# 100              Andrews, Troy
# 101              Andrews, Troy
# 102              Angelou, Maya
#
#                                                title  \
# 0                                      Ace of Spades
# 1                                 Clap When You Land
# 2                                         The Poet X
# 6                              Call Me By Your Name
# 7                             How I Paid for College
# 8                            My Name Is María Isabel
# 9                                       Time to Pray
# 10                       Children of Blood and Bone
# 11                                      47,000 Beads
# 12                              Half of a Yellow Sun
# 13                               Cool for the Summer
# 14     The Accidental Adventures of India McAllister
# 15                                How It All Blew Up
# 17                               Mae Among the Stars
# 18                        Love, Hate & Other Filters
# 20                                  Being the Change
# 22                                      Here's to Us
# 23                                   Kate in Waiting
# 24                              Leah on the Offbeat
# 26                                   Love, Creekwood
# 27                Simon vs. the Homo Sapiens Agenda
# 30                         The Upside of Unrequited
# 33                                  What If It's Us
# 36                                       Indivisible
# 37                                    The Undefeated
# 38                                  The New Jim Crow
# 41   The Absolutely True Diary of a Part-Time Indian
# 57                                   Thunder Boy Jr.
# 58                                    Girls Like Us
# 59                               The Case for Loving
# 60                          The House of the Spirits
# 61                           The Ballad of Ami Miles
# 62                                 Hear These Voices
# 63                                    A is for Audra
# 64                                         Bioethics
# 66                              We Are All Born Free
# 67                                  Bless Me, Ultima
# 68                           The Weight of the Stars
# 69                     Victories Greater Than Death
# 70                                           Neither
# 71                                        White Rage
# 72                                             Shout
# 75                                             Speak
# 81                                              Feed
# 82                            Some Assembly Required
# 83                    Me and Earl and the Dying Girl
# 97                                        The Haters
# 100                               The 5 O'Clock Band
# 101                                  Trombone Shorty
# 102                                 And Still I Rise
#
#                                            description published_date
# 0    Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1    In a novel-in-verse that brims with grief and ...     2020-05-05
# 2    A National Book Award Longlist title! Fans of ...     2019-03-19
# 6                                                  NaN            NaN
# 7                                                  NaN            NaN
# 8                                                  NaN            NaN
# 9                                                  NaN            NaN
# 10                                                 NaN            NaN
# 11   When Peyton doesn't want to wear a dress or da...           2017
# 12   From the award-winning, bestselling author of ...     2007-09-04
# 13                                                 NaN            NaN
# 14   Fourth grade is a year of changes, challenges,...     2010-06-22
# 15   Simon vs. the Homo Sapiens Agenda goes to Ital...     2021-09-28
# 17   An Amazon Best Book of the Month A beautiful p...     2018-01-09
# 18                                                 NaN            NaN
# 20   "This book is about spending time learning abo...           2018
# 22                                                 NaN            NaN
# 23                                                 NaN            NaN
# 24                                                 NaN            NaN
# 26                                                 NaN            NaN
# 27                                                 NaN            NaN
# 30                                                 NaN            NaN
# 33                                                 NaN            NaN
# 36   A timely, moving debut novel about a teen's ef...     2021-05-04
# 37                                                 NaN            NaN
# 38   Named one of the most important nonfiction boo...     2020-01-07
# 41                                                 NaN            NaN
# 57                                                 NaN            NaN
# 58                                                 NaN            NaN
# 59                 The fight for interracial marriage.           2015
# 60                                                 NaN            NaN
# 61                                                 NaN            NaN
# 62   Presents case studies of teenagers living with...           1999
# 63                                                 NaN            NaN
# 64                                                 NaN            NaN
# 66   The Universal Declaration of Human Rights was ...     2016-05-03
# 67   From "one of the nation's foremost Chicano lit...     2012-06-01
# 68   A vivid, evocative YA lesbian romance about ho...     2019-03-19
# 69                                                 NaN            NaN
# 70   In this colorful and touching story that celeb...     2018-03-06
# 71                                                 NaN            NaN
# 72                                                 NaN            NaN
# 75                                                 NaN            NaN
# 81                                                 NaN            NaN
# 82                                                 NaN            NaN
# 83                                                 NaN            NaN
# 97   From Jesse Andrews, author of the New York Tim...     2016-04-05
# 100  This companion title to Trombone Shorty—Caldec...     2020-11-10
# 101                                                NaN            NaN
# 102  Maya Angelou’s unforgettable collection of poe...     2011-08-17

# %%
banned_df['description']
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0       Gossip Girl meets Get Out in Ace of Spades, a ...
# 1       In a novel-in-verse that brims with grief and ...
# 2       A National Book Award Longlist title! Fans of ...
# 6                                                     NaN
# 7                                                     NaN
#                               ...
# 2527                                                  NaN
# 2528                                                  NaN
# 2529                                                  NaN
# 2530                                                  NaN
# 2531                                                  NaN
# Name: description, Length: 1656, dtype: object

# %%
banned_df.to_csv('banned_book_descriptions.csv', index=False)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df = pd.read_csv('banned_book_descriptions.csv')
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655                                                NaN            NaN
#
# [1656 rows x 4 columns]

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author               0
# title                0
# description       1138
# published_date    1132
# dtype: int64

# %%
# we have about 500 descriptions, let's start playing around with this

# %% [markdown]
# We've reached our API limit; we can pull more requests another day.

# %% [markdown]
# ## Iterate more requests
#
# Now that it's another day, we can try pulling more requests.

# %%
banned_df = pd.read_csv('banned_book_descriptions.csv')
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author               0
# title                0
# description       1138
# published_date    1132
# dtype: int64

# %%
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4     A deliciously funny romp of a novel about one ...     2005-08-02
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655  This beautifully illustrated story connects pa...     2019-05-21
#
# [1656 rows x 4 columns]

# %%
import math

df_len = len(banned_df)
import time
batch_size = 50

for i in range(0, df_len, batch_size):
    for j in range(i, min(i+batch_size, df_len)):
        check_value = banned_df.iloc[j]['description']
        try:
          if math.isnan(check_value):
            title = banned_df.iloc[j]['title']
            author = banned_df.iloc[j]['author']
            paste_book_details(title, author)
        except TypeError:
          pass
    time.sleep(120)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author              0
# title               0
# description       620
# published_date    620
# dtype: int64

# %%
banned_df.to_csv('banned_book_descriptions.csv', index=False)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4     A deliciously funny romp of a novel about one ...     2005-08-02
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655  This beautifully illustrated story connects pa...     2019-05-21
#
# [1656 rows x 4 columns]

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author              0
# title               0
# description       620
# published_date    620
# dtype: int64

# %%
# we have over 1000 descriptions!
