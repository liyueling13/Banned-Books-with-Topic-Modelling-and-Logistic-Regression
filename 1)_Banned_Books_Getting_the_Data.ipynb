# %% [markdown]
# <a href="https://colab.research.google.com/github/liyueling13/Predicting-Banned-Books/blob/main/1)_Banned_Books_Getting_the_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PEN America Banned Books -- pulling descriptions and publication date
# 10/30/23

# %% [markdown]
# ## Setup

# %%
# this performs line wrapping on output text in Colab

from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Data Science/Springboard assignments/Capstone Three/Banned Books')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Load Pen America Banned Books

# %%
banned_df = pd.read_csv('PEN America Banned Books.csv', header=None)
columns = ['author', 'title']
banned_df.columns = columns
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 3         Acevedo, Elizabeth
# 4         Acevedo, Elizabeth
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   title
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 3                                            The Poet X
# 4                                            The Poet X
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# 2530  Black Enough: Stories of Being Young & Black i...
# 2531  Grandpa Cacao: A Tale of Chocolate, from Farm ...
#
# [2532 rows x 2 columns]

# %%
banned_df.drop_duplicates(inplace=True)
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author  \
# 0     Àbíké-Íyímídé, Faridah
# 1         Acevedo, Elizabeth
# 2         Acevedo, Elizabeth
# 6              Aciman, André
# 7                Acito, Marc
# ...                      ...
# 2527            Zia, Farhana
# 2528         Ziemke, Kristin
# 2529              Zoboi, Ibi
# 2530              Zoboi, Ibi
# 2531        Zunon, Elizabeth
#
#                                                   title
# 0                                         Ace of Spades
# 1                                    Clap When You Land
# 2                                            The Poet X
# 6     Call Me By Your Name (Call Me By Your Name Ser...
# 7     How I Paid for College: A Novel of Sex, Theft,...
# ...                                                 ...
# 2527                             The Garden of My Imaan
# 2528  Read the World: Rethinking Literacy for Empath...
# 2529                                    American Street
# 2530  Black Enough: Stories of Being Young & Black i...
# 2531  Grandpa Cacao: A Tale of Chocolate, from Farm ...
#
# [1656 rows x 2 columns]

# %%
# remove trailing whitespaces
banned_df = banned_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Let's clean up the dataframe. Some of the titles include subtitles and descriptions. My API call won't work on these. I will remove subtitles/descriptions by dropping everything after a parentheses or colon.

# %%
banned_df['title'] = banned_df['title'].str.replace(r'[:\(\[].*$', '', regex=True)
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 6              Aciman, André   Call Me By Your Name
# 7                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 2527            Zia, Farhana  The Garden of My Imaan
# 2528         Ziemke, Kristin          Read the World
# 2529              Zoboi, Ibi         American Street
# 2530              Zoboi, Ibi            Black Enough
# 2531        Zunon, Elizabeth           Grandpa Cacao
#
# [1656 rows x 2 columns]

# %%
banned_df.drop_duplicates(inplace=True)
banned_df

# %% [markdown]
# ## Let's figure out how to query the Google Books API

# %%
# import requests

# Google Books API key
# API_KEY = redacted
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_book_json(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    print(data)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = "All Boys Aren't Blue"
# author = "Johnson, George M."
# get_book_json(title, author)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# {'kind': 'books#volumes', 'totalItems': 59, 'items': [{'kind': 'books#volume', 'id': 'i0W0DwAAQBAJ', 'etag': '0eJoF1agaJs', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/i0W0DwAAQBAJ', 'volumeInfo': {'title': "All Boys Aren't Blue", 'subtitle': 'A Memoir-Manifesto', 'authors': ['George M. Johnson'], 'publisher': 'Farrar, Straus and Giroux (BYR)', 'publishedDate': '2020-04-28', 'description': "*An Amazon Best Book of the Year optioned for television by Gabrielle Union!* In a series of personal essays, prominent journalist and LGBTQIA+ activist George M. Johnson explores his childhood, adolescence, and college years in New Jersey and Virginia. From the memories of getting his teeth kicked out by bullies at age five, to flea marketing with his loving grandmother, to his first sexual relationships, this young-adult memoir weaves together the trials and triumphs faced by Black queer boys. Both a primer for teens eager to be allies as well as a reassuring testimony for young queer men of color, All Boys Aren't Blue covers topics such as gender identity, toxic masculinity, brotherhood, family, structural marginalization, consent, and Black joy. Johnson's emotionally frank style of writing will appeal directly to young adults.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780374312725'}, {'type': 'ISBN_10', 'identifier': '0374312729'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 320, 'printType': 'BOOK', 'categories': ['Young Adult Nonfiction'], 'averageRating': 1, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '1.3.3.0.preview.2', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=i0W0DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=i0W0DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=i0W0DwAAQBAJ&printsec=frontcover&dq=intitle:All+Boys+Aren%27t+Blue%2Binauthor:Johnson,+George+M.&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=i0W0DwAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=i0W0DwAAQBAJ'}, 'saleInfo': {'country': 'US', 'saleability': 'FOR_SALE', 'isEbook': True, 'listPrice': {'amount': 10.99, 'currencyCode': 'USD'}, 'retailPrice': {'amount': 10.99, 'currencyCode': 'USD'}, 'buyLink': 'https://play.google.com/store/books/details?id=i0W0DwAAQBAJ&rdid=book-i0W0DwAAQBAJ&rdot=1&source=gbs_api', 'offers': [{'finskyOfferType': 1, 'listPrice': {'amountInMicros': 10990000, 'currencyCode': 'USD'}, 'retailPrice': {'amountInMicros': 10990000, 'currencyCode': 'USD'}, 'giftable': True}]}, 'accessInfo': {'country': 'US', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': True, 'acsTokenLink': 'http://books.google.com/books/download/All_Boys_Aren_t_Blue-sample-epub.acsm?id=i0W0DwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'}, 'pdf': {'isAvailable': False}, 'webReaderLink': 'http://play.google.com/books/reader?id=i0W0DwAAQBAJ&hl=&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'In a series of personal essays, prominent journalist and LGBTQIA+ activist George M. Johnson&#39;s All Boys Aren&#39;t Blue explores his childhood, adolescence, and college years in New Jersey and Virginia.'}}, {'kind': 'books#volume', 'id': 'npETEAAAQBAJ', 'etag': '4aOALtep5GI', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/npETEAAAQBAJ', 'volumeInfo': {'title': 'We Are Not Broken', 'authors': ['George M Johnson'], 'publisher': 'Little, Brown Books for Young Readers', 'publishedDate': '2021-09-07', 'description': 'New memoir from George M. Johnson, ...

# %%
def get_book_details(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        if 'items' in data:
            book = data['items'][0]['volumeInfo']
            title = book.get('title', 'N/A')
            authors = ', '.join(book.get('authors', ['N/A']))
            description = book.get('description', 'N/A')
            published_date = book.get('publishedDate', 'N/A')
            print(f'Title: {title}')
            print(f'Authors: {authors}')
            print(f'Description: {description}')
            print(f'Published Date: {published_date}')
        else:
            print('Book not found.')
    else:
        print('Error fetching data from Google Books API.')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = "All Boys Aren't Blue"
# author = "Johnson, George M."
# get_book_details(title, author)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Title: All Boys Aren't Blue
# Authors: George M. Johnson
# Description: *An Amazon Best Book of the Year optioned for television by Gabrielle Union!* In a series of personal essays, prominent journalist and LGBTQIA+ activist George M. Johnson explores his childhood, adolescence, and college years in New Jersey and Virginia. From the memories of getting his teeth kicked out by bullies at age five, to flea marketing with his loving grandmother, to his first sexual relationships, this young-adult memoir weaves together the trials and triumphs faced by Black queer boys. Both a primer for teens eager to be allies as well as a reassuring testimony for young queer men of color, All Boys Aren't Blue covers topics such as gender identity, toxic masculinity, brotherhood, family, structural marginalization, consent, and Black joy. Johnson's emotionally frank style of writing will appeal directly to young adults.
# Published Date: 2020-04-28

# %% [markdown]
# ## Let's pull descriptions and publishing dates from the Google Books API

# %%
from numpy import NaN
banned_df['description'] = NaN
banned_df['published_date'] = NaN
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  description  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades          NaN
# 1         Acevedo, Elizabeth      Clap When You Land          NaN
# 2         Acevedo, Elizabeth              The Poet X          NaN
# 6              Aciman, André   Call Me By Your Name           NaN
# 7                Acito, Marc  How I Paid for College          NaN
# ...                      ...                     ...          ...
# 2527            Zia, Farhana  The Garden of My Imaan          NaN
# 2528         Ziemke, Kristin          Read the World          NaN
# 2529              Zoboi, Ibi         American Street          NaN
# 2530              Zoboi, Ibi            Black Enough          NaN
# 2531        Zunon, Elizabeth           Grandpa Cacao          NaN
#
#       published_date
# 0                NaN
# 1                NaN
# 2                NaN
# 6                NaN
# 7                NaN
# ...              ...
# 2527             NaN
# 2528             NaN
# 2529             NaN
# 2530             NaN
# 2531             NaN
#
# [1656 rows x 4 columns]

# %%
def paste_book_details(title, author):
    base_url = 'https://www.googleapis.com/books/v1/volumes'
    params = {
        'q': f'intitle:{title}+inauthor:{author}',
        'key': API_KEY
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        if 'items' in data:
            book = data['items'][0]['volumeInfo']
            title = book.get('title', 'N/A')
            authors = ', '.join(book.get('authors', ['N/A']))
            description = book.get('description', 'N/A')
            published_date = book.get('publishedDate', 'N/A')
            banned_df.loc[banned_df['title']==title, 'description'] = description
            banned_df.loc[banned_df['title']==title, 'published_date'] = published_date
        else:
            print(f'Title: {title} - Book not found.')
    else:
        print(f'Title: {title} - Error fetching data from Google Books API.')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# title = 'Clap When You Land'
# author = 'Acevedo, Elizabeth'
# paste_book_details(title, author)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# banned_df.loc[banned_df['title']==title]
# it works!
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                author               title  \
# 1  Acevedo, Elizabeth  Clap When You Land
#
#                                          description published_date
# 1  In a novel-in-verse that brims with grief and ...     2020-05-05

# %%
banned_df.iloc[0]['author']
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 'Àbíké-Íyímídé, Faridah'

# %% [markdown]
# Google API has quota limits. I'm limited to 1000 queries per day and 100 queries per min. So I will do this iteratively in 50s and wait a couple minutes between each query.

# %%
# df_len = len(banned_df)

# import time
# batch_size = 50

# for i in range(0, df_len, batch_size):
  #   for j in range(i, min(i+batch_size, total_items)):
    #   title = banned_df.iloc[j]['title']
    #   author = banned_df.iloc[j]['author']
    #   paste_book_details(title, author)
  #   time.sleep(60)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Title: How I Paid for College - Error fetching data from Google Books API.
# Title: My Name Is María Isabel - Error fetching data from Google Books API.
# Title: Time to Pray - Error fetching data from Google Books API.
# Title: Cool for the Summer - Error fetching data from Google Books API.
# Title: Here's to Us - Error fetching data from Google Books API.
# Title: Kate in Waiting - Error fetching data from Google Books API.
# Title: Simon vs. the Homo Sapiens Agenda  - Error fetching data from Google Books API.
# Title: The Upside of Unrequited  - Error fetching data from Google Books API.
# Title: The Undefeated - Error fetching data from Google Books API.
# Title: Thunder Boy Jr. - Error fetching data from Google Books API.
# Title: The House of the Spirits - Error fetching data from Google Books API.
# Title: The Ballad of Ami Miles - Error fetching data from Google Books API.
# Title: A is for Audra - Error fetching data from Google Books API.
# Title: Bioethics - Error fetching data from Google Books API.
# Title: White Rage - Error fetching data from Google Books API.
# Title: Shout - Error fetching data from Google Books API.
# Title: Speak - Error fetching data from Google Books API.
# Title: Feed - Error fetching data from Google Books API.
# Title: Some Assembly Required - Error fetching data from Google Books API.
# Title: Me and Earl and the Dying Girl - Error fetching data from Google Books API.
# Title: Trombone Shorty - Error fetching data from Google Books API.
# Title: I Know Why The Caged Bird Sings - Error fetching data from Google Books API.
# Title: Modern Romance - Error fetching data from Google Books API.
# Title: Duels and Deception - Error fetching data from Google Books API.
# Title: LGBTQ Families - Error fetching data from Google Books API.
# Title: Wishtree - Error fetching data from Google Books API.
# Title: Meet Cute - Error fetching data from Google Books API.
# Title: A Boy Called Bat  - Error fetching data from Google Books API.
# Title: Bat and the End of Everything  - Error fetching data from Google Books API.
# Title: Bat and the Waiting Game  - Error fetching data from Google Books API.
# Title: Infandous - Error fetching data from Google Books API.
# Title: A Girl on the Shore - Error fetching data from Google Books API.
# Title: Thirteen Reasons Why - Error fetching data from Google Books API.
# Title: The Handmaid's Tale - Error fetching data from Google Books API.
# Title: The Handmaid's Tale - Error fetching data from Google Books API.
# Title: The Testaments - Error fetching data from Google Books API.
# Title: Worm Loves Worm - Error fetching data from Google Books API.
# Title: Morris Micklewhite and the Tangerine Dress - Error fetching data from Google Books API.
# Title: One Man Guy - Error fetching data from Google Books API.
# Title: Six of Crows  - Error fetching data from Google Books API.
# Title: Brand New School, Brave New Ruby  - Error fetching data from Google Books API.
# Title: Crown - Error fetching data from Google Books API.
# Title: Slumber Party Payback  - Error fetching data from Google Books API.
# Title: No Mirrors in My Nana's House - Error fetching data from Google Books API.
# Title: Tears of Frost  - Error fetching data from Google Books API.
# Title: Wonders of the Invisible World - Error fetching data from Google Books API.
# Title: Girls Made of Snow and Glass - Error fetching data from Google Books API.
# Title: Sofia Valdez, Future Prez  - Error fetching data from Google Books API.
# Title: Fun Home - Error fetching data from Google Books API.
# Title: Queer - Error fetching data from Google Books API.
# Title: Faces at the Bottom of the Well - Error fetching data from Google Books API.
# Title: Alan Cole Is Not a Coward - Error fetching data from Google Books API.
# Title: Death Wind - Error fetching data from Google Books API.
# Title: La tormenta - Error fetching data from Google Books API.
# Title: Things That Make White People Uncomfortable  - Error fetching data from Google Books API.
# Title: Far from the Tree - Error fetching data from Google Books API.
# Title: Kaleidoscope Song - Error fetching data from Google Books API.
# Title: The Berenstain Bears and the Big Question  - Error fetching data from Google Books API.
# Title: Trans Mission - Error fetching data from Google Books API.
# Title: Being Transgender - Error fetching data from Google Books API.
# Title: The Sin-Eater's Confession - Error fetching data from Google Books API.
# Title: Marvelous Cornelius - Error fetching data from Google Books API.
# Title: Most Valuable Players  - Error fetching data from Google Books API.
# Title: Playing the Field - Error fetching data from Google Books API.
# Title: The Baby Tree - Error fetching data from Google Books API.
# Title: Boy2Girl - Error fetching data from Google Books API.
# Title: Girl Made of Stars - Error fetching data from Google Books API.
# Title: How to Make a Wish - Error fetching data from Google Books API.
# Title: La carta de Ivy Aberdeen al mundo/Ivy Aberdeen's Letter to the World - Book not found.
# Title: Bowery Girl - Error fetching data from Google Books API.
# Title: Forever... - Book not found.
# Title: Jane Against the World - Error fetching data from Google Books API.
# Title: A Bike Like Sergio's - Error fetching data from Google Books API.
# Title: Those Shoes - Error fetching data from Google Books API.
# Title: Changing the Equation - Error fetching data from Google Books API.
# Title: Sasha Masha - Error fetching data from Google Books API.
# Title: Channel Kindness - Error fetching data from Google Books API.
# Title: Be Gay, Do Comics - Book not found.
# Title: Kings, Queens, and In-Betweens - Error fetching data from Google Books API.
# Title: Allies - Error fetching data from Google Books API.
# Title: The Witch Owl Parliament  - Error fetching data from Google Books API.
# Title: Summer Bird Blue - Error fetching data from Google Books API.
# Title: The Benefits of Being an Octopus - Error fetching data from Google Books API.
# Title: Ziggy, Stardust and Me - Error fetching data from Google Books API.
# Title: Protest Movements - Error fetching data from Google Books API.
# Title: Into the Real - Error fetching data from Google Books API.
# Title: Imani's Moon - Error fetching data from Google Books API.
# Title: Who Is Malala Yousafzai?  - Error fetching data from Google Books API.
# Title: Black Girl Unlimited - Error fetching data from Google Books API.
# Title: The Meaning of Birds - Error fetching data from Google Books API.
# Title: Lola Levine and the Vacation Dream  - Error fetching data from Google Books API.
# Title: Lola Levine Is Not Mean!  - Error fetching data from Google Books API.
# Title: Lola Levine - Error fetching data from Google Books API.
# Title: My Name Is Celia - Error fetching data from Google Books API.
# Title: Pele, King of Soccer/Pele, El rey del futbol - Error fetching data from Google Books API.
# Title: Tito Puente, Mambo King/Tito Puente, Rey del Mambo - Error fetching data from Google Books API.
# Title: The Truth about Keeping Secrets - Error fetching data from Google Books API.
# Title: Crazy Horse's Vision - Error fetching data from Google Books API.
# Title: Eagle Song - Error fetching data from Google Books API.
# Title: Squanto's Journey - Error fetching data from Google Books API.
# Title: The First Strawberries - Error fetching data from Google Books API.
# Title: Thirteen Moons on Turtle's Back - Error fetching data from Google Books API.
# Title: Alex As Well - Error fetching data from Google Books API.
# Title: 101 Questions About Reproduction - Error fetching data from Google Books API.
# Title: 101 Questions About Sex and Sexuality - Error fetching data from Google Books API.
# Title: Who Was Jesse Owens?  - Error fetching data from Google Books API.
# Title: Eagle Feather - Error fetching data from Google Books API.
# Title: Zenobia July - Error fetching data from Google Books API.
# Title: A Day's Work - Error fetching data from Google Books API.
# Title: One Green Apple - Error fetching data from Google Books API.
# Title: Smoky Night - Error fetching data from Google Books API.
# Title: The Vast Fields of Ordinary - Error fetching data from Google Books API.
# Title: How to Be Ace - Error fetching data from Google Books API.
# Title: King & Kayla and the Case of Found Fred  - Error fetching data from Google Books API.
# Title: King & Kayla and the Case of the Lost Library Book  - Error fetching data from Google Books API.
# Title: King & Kayla and the Case of the Lost Tooth  - Error fetching data from Google Books API.
# Title: King & Kayla and the Case of the Mysterious Mouse  - Error fetching data from Google Books API.
# Title: I Am Enough - Error fetching data from Google Books API.
# Title: Ready or Not  - Error fetching data from Google Books API.
# Title: Felix Ever After - Error fetching data from Google Books API.
# Title: This Is Kind of an Epic Love Story - Error fetching data from Google Books API.
# Title: Echo After Echo - Error fetching data from Google Books API.
# Title: Once & Future - Error fetching data from Google Books API.
# Title: Sword in the Stars  - Error fetching data from Google Books API.
# Title: Be Strong, Be Wise - Error fetching data from Google Books API.
# Title: Love & Sex - Book not found.
# Title: My Best Friend, Maybe - Error fetching data from Google Books API.
# Title: Graceling  - Error fetching data from Google Books API.
# Title: Jane, Unlimited - Error fetching data from Google Books API.
# Title: Awakened  - Error fetching data from Google Books API.
# Title: Burned  - Error fetching data from Google Books API.
# Title: Destined  - Error fetching data from Google Books API.
# Title: Hidden  - Error fetching data from Google Books API.
# Title: Hunted  - Error fetching data from Google Books API.
# Title: Redeemed  - Error fetching data from Google Books API.
# Title: Revealed  - Error fetching data from Google Books API.
# Title: Tempted  - Error fetching data from Google Books API.
# Title: Untamed  - Error fetching data from Google Books API.
# Title: Something Happened in Our Town - Error fetching data from Google Books API.
# Title: The Rape of Nanking - Error fetching data from Google Books API.
# Title: Homecoming  - Error fetching data from Google Books API.
# Title: Rebel Girl Revolution  - Error fetching data from Google Books API.
# Title: The Perks of Being a Wallflower - Error fetching data from Google Books API.
# Title: The Year of the Book  - Error fetching data from Google Books API.
# Title: Hair Love - Error fetching data from Google Books API.
# Title: Brother Eagle, Sister Sky - Error fetching data from Google Books API.
# Title: Amelia to Zora - Error fetching data from Google Books API.
# Title: Sam and the Lucky Money - Error fetching data from Google Books API.
# Title: Brave  - Error fetching data from Google Books API.
# Title: The House on Mango Street - Error fetching data from Google Books API.
# Title: City of Heavenly Fire  - Error fetching data from Google Books API.
# Title: Clockwork Princess  - Error fetching data from Google Books API.
# Title: The Red Scrolls of Magic  - Error fetching data from Google Books API.
# Title: Let the Children March - Error fetching data from Google Books API.
# Title: Freakboy - Error fetching data from Google Books API.
# Title: Jess, Chunk, and the Road Trip to Infinity - Error fetching data from Google Books API.
# Title: Forget This Ever Happened - Error fetching data from Google Books API.
# Title: The Pants Project - Error fetching data from Google Books API.
# Title: Extra Credit - Error fetching data from Google Books API.
# Title: Before She Was Harriet - Error fetching data from Google Books API.
# Title: Between the World and Me - Error fetching data from Google Books API.
# Title: We Were Eight Years in Power - Error fetching data from Google Books API.
# Title: Sadako - Error fetching data from Google Books API.
# Title: Imbeciles - Error fetching data from Google Books API.
# Title: Thank You, Jackie Robinson - Error fetching data from Google Books API.
# Title: The Mud Pony - Error fetching data from Google Books API.
# Title: Gingerbread  - Error fetching data from Google Books API.
# Title: Naomi and Ely's No Kiss List - Error fetching data from Google Books API.
# Title: The Kingdom of Little Wounds - Error fetching data from Google Books API.
# Title: Little & Lion - Error fetching data from Google Books API.
# Title: The Facts Speak for Themselves - Error fetching data from Google Books API.
# Title: The Story of Ruby Bridges - Error fetching data from Google Books API.
# Title: The Traitor Game - Error fetching data from Google Books API.
# Title: All the Invisible Things - Error fetching data from Google Books API.
# Title: Boy Erased - Error fetching data from Google Books API.
# Title: A Home for Goddesses and Dogs - Error fetching data from Google Books API.
# Title: The Life of Rosa Parks  - Error fetching data from Google Books API.
# Title: Short Stuff - Book not found.
# Title: Notes from the Blender - Error fetching data from Google Books API.
# Title: Full, Full, Full of Love - Error fetching data from Google Books API.
# Title: Max and the Tag-Along Moon - Error fetching data from Google Books API.
# Title: Bruja Born  - Error fetching data from Google Books API.
# Title: Wayward Witch  - Error fetching data from Google Books API.
# Title: Wait, What? - Error fetching data from Google Books API.
# Title: Jabari Jumps  - Error fetching data from Google Books API.
# Title: A Dream Come True - Error fetching data from Google Books API.
# Title: The Sky Blues - Error fetching data from Google Books API.
# Title: Of Fire and Stars  - Error fetching data from Google Books API.
# Title: Class Act - Error fetching data from Google Books API.
# Title: New Kid - Error fetching data from Google Books API.
# Title: Walk Two Moons - Error fetching data from Google Books API.
# Title: Rift  - Error fetching data from Google Books API.
# Title: Beautiful Music for Ugly Children - Error fetching data from Google Books API.
# Title: Striving for Equality - Error fetching data from Google Books API.
# Title: Staying Fat for Sarah Byrnes - Error fetching data from Google Books API.
# Title: Flamer - Error fetching data from Google Books API.
# Title: LGBT Families  - Error fetching data from Google Books API.
# Title: A Peacock Among Pigeons - Error fetching data from Google Books API.
# Title: The Mighty Miss Malone - Error fetching data from Google Books API.
# Title: Dreadnought  - Error fetching data from Google Books API.
# Title: Happy families - Error fetching data from Google Books API.
# Title: This Book Is Gay - Error fetching data from Google Books API.
# Title: Understanding Gender - Error fetching data from Google Books API.
# Title: The Boy I Love - Error fetching data from Google Books API.
# Title: I'm a Wild Seed - Error fetching data from Google Books API.
# Title: Carmela Full of Wishes - Error fetching data from Google Books API.
# Title: Mexican Whiteboy - Error fetching data from Google Books API.
# Title: The Gods of Tango - Error fetching data from Google Books API.
# Title: I Wish You All the Best  - Error fetching data from Google Books API.
# Title: Maybe He Just Likes You - Error fetching data from Google Books API.
# Title: Star-Crossed - Error fetching data from Google Books API.
# Title: 14 Cows for America - Error fetching data from Google Books API.
# Title: Teaching When the World Is on Fire - Error fetching data from Google Books API.
# Title: The Legend of the Bluebonnet  - Error fetching data from Google Books API.
# Title: Cece Loves Science  - Error fetching data from Google Books API.
# Title: Gender Equality  - Error fetching data from Google Books API.
# Title: I Think I Love You - Error fetching data from Google Books API.
# Title: Team BFF - Error fetching data from Google Books API.
# Title: A Better Bad Idea - Error fetching data from Google Books API.
# Title: White Fragility - Error fetching data from Google Books API.
# Title: Islandborn - Error fetching data from Google Books API.
# Title: The Friend Scheme - Error fetching data from Google Books API.
# Title: The Love Interest - Error fetching data from Google Books API.
# Title: Mixed Me! - Error fetching data from Google Books API.
# Title: Rap a Tap Tap - Error fetching data from Google Books API.
# Title: The Legend of Korra - Error fetching data from Google Books API.
# Title: The Legend of Korra - Error fetching data from Google Books API.
# Title: The Legend of Korra - Error fetching data from Google Books API.
# Title: You and Me and Him - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: WeirDo Series - Error fetching data from Google Books API.
# Title: More Than a Game - Error fetching data from Google Books API.
# Title: Ashes to Asheville - Error fetching data from Google Books API.
# Title: Abuela - Error fetching data from Google Books API.
# Title: Narrative of the Life of Frederick Douglass - Error fetching data from Google Books API.
# Title: Unbecoming - Error fetching data from Google Books API.
# Title: Blended - Error fetching data from Google Books API.
# Title: Darkness Before Dawn - Error fetching data from Google Books API.
# Title: Forged By Fire - Error fetching data from Google Books API.
# Title: Romiette and Julio - Error fetching data from Google Books API.
# Title: Hot Dog Girl - Error fetching data from Google Books API.
# Title: Verona Comics - Error fetching data from Google Books API.
# Title: It Ain't So Awful, Falafel - Error fetching data from Google Books API.
# Title: Attack of the Swamp Thing  - Error fetching data from Google Books API.
# Title: Mission Star-Power  - Error fetching data from Google Books API.
# Title: The Ladek Invasion  - Error fetching data from Google Books API.
# Title: The Quest for Screen Time  - Error fetching data from Google Books API.
# Title: An Indigenous Peoples' History of the United States - Error fetching data from Google Books API.
# Title: We Are Lost and Found - Error fetching data from Google Books API.
# Title: Killing Mr. Griffin - Error fetching data from Google Books API.
# Title: A Perfect Blank - Error fetching data from Google Books API.
# Title: The Girl Who Fell from the Sky - Error fetching data from Google Books API.
# Title: The Art of Saving the World - Error fetching data from Google Books API.
# Title: Enough! 20 Protesters Who Changed America - Error fetching data from Google Books API.
# Title: The Witch King  - Error fetching data from Google Books API.
# Title: Who Is Barack Obama?  - Error fetching data from Google Books API.
# Title: After - Error fetching data from Google Books API.
# Title: The Circle  - Error fetching data from Google Books API.
# Title: Milo's Museum - Error fetching data from Google Books API.
# Title: Say Her Name - Error fetching data from Google Books API.
# Title: May the Best Man Win - Error fetching data from Google Books API.
# Title: Home at Last - Error fetching data from Google Books API.
# Title: For White Folks Who Teach in the Hood... and the Rest of Y'all Too - Error fetching data from Google Books API.
# Title: Pet - Error fetching data from Google Books API.
# Title: A Dog Named Haku - Error fetching data from Google Books API.
# Title: Drum Dream Girl - Error fetching data from Google Books API.
# Title: Hot Day on Abbott Avenue - Error fetching data from Google Books API.
# Title: Nadia's Hands - Error fetching data from Google Books API.
# Title: Nikki & Deja  - Error fetching data from Google Books API.
# Title: En Comunidad - Error fetching data from Google Books API.
# Title: Birth Control - Error fetching data from Google Books API.
# Title: Teach Us Your Name - Error fetching data from Google Books API.
# Title: Middlesex - Error fetching data from Google Books API.
# Title: We March - Error fetching data from Google Books API.
# Title: Girl, Woman, Other - Error fetching data from Google Books API.
# Title: Lawn Boy - Error fetching data from Google Books API.
# Title: 10,000 Dresses - Error fetching data from Google Books API.
# Title: Who Was Frida Kahlo?  - Error fetching data from Google Books API.
# Title: Who Was Rachel Carson?  - Error fetching data from Google Books API.
# Title: My Heart Underwater - Error fetching data from Google Books API.
# Title: If You Could Be Mine - Error fetching data from Google Books API.
# Title: Tell Me Again How a Crush Should Feel - Error fetching data from Google Books API.
# Title: The Abortion Debate  - Error fetching data from Google Books API.
# Title: With Or Without You - Error fetching data from Google Books API.
# Title: Lailah's Lunchbox - Error fetching data from Google Books API.
# Title: A Place at the Table - Error fetching data from Google Books API.
# Title: Yasmin the Builder  - Error fetching data from Google Books API.
# Title: Yasmin the Explorer  - Error fetching data from Google Books API.
# Title: Yasmin the Fashionista  - Error fetching data from Google Books API.
# Title: Yasmin the Painter  - Error fetching data from Google Books API.
# Title: Yasmin the Recycler  - Error fetching data from Google Books API.
# Title: Yasmin the Scientist  - Error fetching data from Google Books API.
# Title: Yasmin the Singer  - Error fetching data from Google Books API.
# Title: Yasmin the Soccer Star  - Error fetching data from Google Books API.
# Title: Yasmin the Superhero  - Error fetching data from Google Books API.
# Title: Yasmin the Teacher  - Error fetching data from Google Books API.
# Title: Yasmin the Writer  - Error fetching data from Google Books API.
# Title: Yasmin the Zookeeper  - Error fetching data from Google Books API.
# Title: Roe v. Wade - Error fetching data from Google Books API.
# Title: Nate Expectations - Error fetching data from Google Books API.
# Title: The Sissy Duckling - Error fetching data from Google Books API.
# Title: Phoenix Goes to School - Error fetching data from Google Books API.
# Title: The Sweet Revenge of Celia Door - Error fetching data from Google Books API.
# Title: Hook Up - Error fetching data from Google Books API.
# Title: Who Am I Without Him? - Error fetching data from Google Books API.
# Title: Seedfolks - Error fetching data from Google Books API.
# Title: Tattoo Atlas - Error fetching data from Google Books API.
# Title: Willful Machines - Error fetching data from Google Books API.
# Title: Jasmine Toguchi, Drummer Girl  - Error fetching data from Google Books API.
# Title: Jasmine Toguchi, Flamingo Keeper  - Error fetching data from Google Books API.
# Title: Jasmine Toguchi, Mochi Queen  - Error fetching data from Google Books API.
# Title: Jasmine Toguchi, Super Sleuth  - Error fetching data from Google Books API.
# Title: Extremely Loud & Incredibly Close - Error fetching data from Google Books API.
# Title: Anne Frank's Diary - Error fetching data from Google Books API.
# Title: Suicide Notes - Error fetching data from Google Books API.
# Title: I Was Here - Error fetching data from Google Books API.
# Title: Dime - Error fetching data from Google Books API.
# Title: Not Quite Snow White - Error fetching data from Google Books API.
# Title: Tessa Masterson Will Go to Prom - Error fetching data from Google Books API.
# Title: Bingo Love #1 - Error fetching data from Google Books API.
# Title: Cheer Up - Error fetching data from Google Books API.
# Title: The Black Friend - Error fetching data from Google Books API.
# Title: Monster Trouble! - Error fetching data from Google Books API.
# Title: Pedagogy of the Oppressed - Error fetching data from Google Books API.
# Title: All Eyes on Us - Error fetching data from Google Books API.
# Title: The Double Life of Pocahontas - Error fetching data from Google Books API.
# Title: African American Cowboys - Error fetching data from Google Books API.
# Title: A Quick & Easy Guide to Queer & Trans Identities - Error fetching data from Google Books API.
# Title: Outlander  - Error fetching data from Google Books API.
# Title: When We Were Magic - Error fetching data from Google Books API.
# Title: A Lesson Before Dying - Error fetching data from Google Books API.
# Title: Ho'onani - Error fetching data from Google Books API.
# Title: Lobizona  - Error fetching data from Google Books API.
# Title: Lobizona - Error fetching data from Google Books API.
# Title: Caraval  - Error fetching data from Google Books API.
# Title: Dreaming in Cuban - Error fetching data from Google Books API.
# Title: Escuchando con mi Corazón - Error fetching data from Google Books API.
# Title: Cow on the Town - Error fetching data from Google Books API.
# Title: Annie on My Mind - Error fetching data from Google Books API.
# Title: Hear Us Out! - Error fetching data from Google Books API.
# Title: The Year They Burned the Books - Error fetching data from Google Books API.
# Title: Girl on the Line - Error fetching data from Google Books API.
# Title: Symptoms of Being Human - Error fetching data from Google Books API.
# Title: Culturally Responsive Teaching - Error fetching data from Google Books API.
# Title: Hunger - Error fetching data from Google Books API.
# Title: Fancy White Trash - Error fetching data from Google Books API.
# Title: My Mixed-Up Berry Blue Summer - Error fetching data from Google Books API.
# Title: The Edge of the Water  - Error fetching data from Google Books API.
# Title: Luis Munoz Marin  - Error fetching data from Google Books API.
# Title: The Difference Between You and Me - Error fetching data from Google Books API.
# Title: Lily and Dunkin - Error fetching data from Google Books API.
# Title: Girls Like Us  - Error fetching data from Google Books API.
# Title: Not So Pure and Simple - Error fetching data from Google Books API.
# Title: Melissa  - Error fetching data from Google Books API.
# Title: Rick - Error fetching data from Google Books API.
# Title: Hope and Healing in Urban Education - Error fetching data from Google Books API.
# Title: Girl Mans Up - Error fetching data from Google Books API.
# Title: Joshua and the City - Error fetching data from Google Books API.
# Title: After the Game  - Error fetching data from Google Books API.
# Title: Losing the Field  - Error fetching data from Google Books API.
# Title: Making a Play  - Error fetching data from Google Books API.
# Title: The Vincent Boys  - Error fetching data from Google Books API.
# Title: The Vincent Brothers  - Error fetching data from Google Books API.
# Title: Under the Lights  - Error fetching data from Google Books API.
# Title: Until the End  - Error fetching data from Google Books API.
# Title: The Hula-Hoopin' Queen - Error fetching data from Google Books API.
# Title: Roe v. Wade - Error fetching data from Google Books API.
# Title: Two Parties, One Tux, and a Very Short Film about The Grapes of Wrath - Error fetching data from Google Books API.
# Title: The Sound of Silence - Error fetching data from Google Books API.
# Title: Love & Other Carnivorous Plants - Error fetching data from Google Books API.
# Title: Trans+ - Error fetching data from Google Books API.
# Title: Perfect on Paper - Error fetching data from Google Books API.
# Title: They, She, He Easy as ABC - Error fetching data from Google Books API.
# Title: What Drowns the Flowers in Your Mouth - Error fetching data from Google Books API.
# Title: All Around Us - Error fetching data from Google Books API.
# Title: Sister Mischief - Error fetching data from Google Books API.
# Title: How Not to Ask a Boy to Prom - Error fetching data from Google Books API.
# Title: Whatever. - Error fetching data from Google Books API.
# Title: Forever for a Year - Error fetching data from Google Books API.
# Title: The Handsome Girl & Her Beautiful Boy - Error fetching data from Google Books API.
# Title: The Nerdy and the Dirty - Error fetching data from Google Books API.
# Title: Seeing Gender - Error fetching data from Google Books API.
# Title: Amelia Westlake Was Never Here - Error fetching data from Google Books API.
# Title: Cross My Heart  - Error fetching data from Google Books API.
# Title: Who Was Maria Tallchief?  - Error fetching data from Google Books API.
# Title: Image and Identity - Error fetching data from Google Books API.
# Title: Night Shine  - Error fetching data from Google Books API.
# Title: Refugee - Error fetching data from Google Books API.
# Title: Let it Snow - Error fetching data from Google Books API.
# Title: Looking for Alaska - Error fetching data from Google Books API.
# Title: Will Grayson, Will Grayson  - Error fetching data from Google Books API.
# Title: Lighter than My Shadow - Error fetching data from Google Books API.
# Title: Rosa Parks - Error fetching data from Google Books API.
# Title: The Great Migration - Error fetching data from Google Books API.
# Title: Hooked - Error fetching data from Google Books API.
# Title: None of the Above - Error fetching data from Google Books API.
# Title: The Deepest Breath - Error fetching data from Google Books API.
# Title: Make Way for Dyamonde Daniel  - Error fetching data from Google Books API.
# Title: Ordinary Hazards - Error fetching data from Google Books API.
# Title: Fates and Furies - Error fetching data from Google Books API.
# Title: Water for Elephants - Error fetching data from Google Books API.
# Title: Leila in Saffron - Error fetching data from Google Books API.
# Title: Homegoing - Error fetching data from Google Books API.
# Title: Prince & Knight  - Error fetching data from Google Books API.
# Title: Culturally Responsive Teaching and The Brain - Error fetching data from Google Books API.
# Title: To All the Boys I've Loved Before  - Error fetching data from Google Books API.
# Title: The Abortion Debate - Error fetching data from Google Books API.
# Title: The Art of Fielding - Error fetching data from Google Books API.
# Title: The Last Exit to Normal - Error fetching data from Google Books API.
# Title: Dead Until Dark  - Error fetching data from Google Books API.
# Title: Political Resistance in the Current Age - Error fetching data from Google Books API.
# Title: It's Perfectly Normal - Error fetching data from Google Books API.
# Title: Little Leaders - Error fetching data from Google Books API.
# Title: Little Legends - Error fetching data from Google Books API.
# Title: Geography Club  - Error fetching data from Google Books API.
# Title: What We Saw - Error fetching data from Google Books API.
# Title: Ramadan Around The World - Error fetching data from Google Books API.
# Title: Her Royal Highness - Error fetching data from Google Books API.
# Title: Her Royal Highness  - Error fetching data from Google Books API.
# Title: Girl Crushed - Error fetching data from Google Books API.
# Title: The Day of Ahmed's Secret - Error fetching data from Google Books API.
# Title: Promposal - Error fetching data from Google Books API.
# Title: 100 Questions You'd Never Ask Your Parents - Error fetching data from Google Books API.
# Title: Unpregnant - Error fetching data from Google Books API.
# Title: The Other Boy - Error fetching data from Google Books API.
# Title: Ask Me How I Got Here - Error fetching data from Google Books API.
# Title: The Devouring Gray  - Error fetching data from Google Books API.
# Title: Who Is Derek Jeter?  - Error fetching data from Google Books API.
# Title: Sal and Gabi Break the Universe  - Error fetching data from Google Books API.
# Title: The War Outside - Error fetching data from Google Books API.
# Title: Not My Idea - Error fetching data from Google Books API.
# Title: Rethinking Normal - Error fetching data from Google Books API.
# Title: When the Beat Was Born - Error fetching data from Google Books API.
# Title: Black Lives Matter - Error fetching data from Google Books API.
# Title: The Birds, the Bees, and You and Me - Error fetching data from Google Books API.
# Title: The Outsiders - Error fetching data from Google Books API.
# Title: The Night Diary - Error fetching data from Google Books API.
# Title: One True Way - Error fetching data from Google Books API.
# Title: Hush! A Thai Lullaby - Error fetching data from Google Books API.
# Title: Archenemy - Error fetching data from Google Books API.
# Title: Best Best Colors - Error fetching data from Google Books API.
# Title: Amazing Grace  - Error fetching data from Google Books API.
# Title: Jacob's New Dress - Error fetching data from Google Books API.
# Title: Jacob's Room to Choose - Error fetching data from Google Books API.
# Title: Hang-ups, Hook-ups, and Holding Out - Error fetching data from Google Books API.
# Title: Redwood and Ponytail - Error fetching data from Google Books API.
# Title: Jack - Error fetching data from Google Books API.
# Title: Teaching to Transgress - Error fetching data from Google Books API.
# Title: Burned  - Error fetching data from Google Books API.
# Title: Crank  - Error fetching data from Google Books API.
# Title: Fallout  - Error fetching data from Google Books API.
# Title: Identical - Error fetching data from Google Books API.
# Title: People Kill People - Error fetching data from Google Books API.
# Title: Perfect  - Error fetching data from Google Books API.
# Title: Smoke  - Error fetching data from Google Books API.
# Title: Tilt - Error fetching data from Google Books API.
# Title: Traffick  - Error fetching data from Google Books API.
# Title: Triangles - Error fetching data from Google Books API.
# Title: Tricks  - Error fetching data from Google Books API.
# Title: Carter Reads the Newspaper - Error fetching data from Google Books API.
# Title: Michelle - Error fetching data from Google Books API.
# Title: What Is the Women's Rights Movement?  - Error fetching data from Google Books API.
# Title: A Love Story Starring My Dead Best Friend - Error fetching data from Google Books API.
# Title: The Kite Runner - Error fetching data from Google Books API.
# Title: Virgie Goes to School with Us Boys - Error fetching data from Google Books API.
# Title: Middle School's a Drag, You Better Werk! - Error fetching data from Google Books API.
# Title: The Whispers - Error fetching data from Google Books API.
# Title: Totally Joe  - Error fetching data from Google Books API.
# Title: Teen Legal Rights - Error fetching data from Google Books API.
# Title: My Friend Maya Loves to Dance - Error fetching data from Google Books API.
# Title: GLBTQ* - Error fetching data from Google Books API.
# Title: No Girls Allowed - Error fetching data from Google Books API.
# Title: Their Eyes Were Watching God - Error fetching data from Google Books API.
# Title: Freaks and Revelations - Error fetching data from Google Books API.
# Title: A Complicated Love Story Set in Space - Error fetching data from Google Books API.
# Title: Brave Face - Error fetching data from Google Books API.
# Title: We Are the Ants - Error fetching data from Google Books API.
# Title: Brave New World - Error fetching data from Google Books API.
# Title: Jumpstart the World - Error fetching data from Google Books API.
# Title: Safe Sex 101 - Error fetching data from Google Books API.
# Title: Shirley Jackson's "The Lottery" - Error fetching data from Google Books API.
# Title: Fragile Remedy - Error fetching data from Google Books API.
# Title: The Cider House Rules - Error fetching data from Google Books API.
# Title: Speak No Evil - Error fetching data from Google Books API.
# Title: Good Girl, Bad Blood  - Error fetching data from Google Books API.
# Title: Yesterday Is History - Error fetching data from Google Books API.
# Title: Let Me Hear a Rhyme - Error fetching data from Google Books API.
# Title: Monday's Not Coming - Error fetching data from Google Books API.
# Title: Stained - Error fetching data from Google Books API.
# Title: The Henna Wars - Error fetching data from Google Books API.
# Title: Fifty Shades of Grey  - Error fetching data from Google Books API.
# Title: I Promise - Error fetching data from Google Books API.
# Title: When Stars Are Scattered - Error fetching data from Google Books API.
# Title: The Year Shakespeare Ruined My Life - Error fetching data from Google Books API.
# Title: The Dark Tide - Error fetching data from Google Books API.
# Title: Soccer Star - Error fetching data from Google Books API.
# Title: I am Jazz - Error fetching data from Google Books API.
# Title: Invisible Girl - Error fetching data from Google Books API.
# Title: Red Kite, Blue Kite - Error fetching data from Google Books API.
# Title: IntersectionAllies - Error fetching data from Google Books API.
# Title: A Sweet Smell of Roses - Error fetching data from Google Books API.
# Title: The Breakaways - Error fetching data from Google Books API.
# Title: All Boys Aren't Blue - Error fetching data from Google Books API.
# Title: We Are Not Broken - Error fetching data from Google Books API.
# Title: Target - Error fetching data from Google Books API.
# Title: This Is My America - Error fetching data from Google Books API.
# Title: Speak for Yourself - Error fetching data from Google Books API.
# Title: Rise to the Sun - Error fetching data from Google Books API.
# Title: You Should See Me in a Crown - Error fetching data from Google Books API.
# Title: The Shark King - Error fetching data from Google Books API.
# Title: My Life as a Rhombus - Error fetching data from Google Books API.
# Title: The Parker Inheritance - Error fetching data from Google Books API.
# Title: What Were the Negro Leagues?  - Error fetching data from Google Books API.
# Title: That Inevitable Victorian Thing - Error fetching data from Google Books API.
# Title: The Afterward - Error fetching data from Google Books API.
# Title: Any Small Goodness - Error fetching data from Google Books API.
# Title: Day of the Dead - Error fetching data from Google Books API.
# Title: Fire Song - Error fetching data from Google Books API.
# Title: Tips on Having a Gay  - Error fetching data from Google Books API.
# Title: Master of One - Error fetching data from Google Books API.
# Title: Unusual Chickens for the Exceptional Poultry Farmer  - Error fetching data from Google Books API.
# Title: Combat Zone - Error fetching data from Google Books API.
# Title: My Two Dads and Me - Error fetching data from Google Books API.
# Title: My Two Moms and Me - Error fetching data from Google Books API.
# Title: Fatty Legs - Error fetching data from Google Books API.
# Title: The Color of My Words - Error fetching data from Google Books API.
# Title: Another Kind of Cowboy - Error fetching data from Google Books API.
# Title: Abortion - Error fetching data from Google Books API.
# Title: Abuela's Birthday  - Error fetching data from Google Books API.
# Title: Abuela's Special Letters  - Error fetching data from Google Books API.
# Title: Hector's Hiccups  - Error fetching data from Google Books API.
# Title: Lights Out  - Error fetching data from Google Books API.
# Title: My Family Adventure  - Error fetching data from Google Books API.
# Title: My Fantástica Family  - Error fetching data from Google Books API.
# Title: My Vida Loca  - Error fetching data from Google Books API.
# Title: Never Say a Mean Word Again - Error fetching data from Google Books API.
# Title: Picture Perfect  - Error fetching data from Google Books API.
# Title: Shopping Trip Trouble  - Error fetching data from Google Books API.
# Title: Singing Superstar  - Error fetching data from Google Books API.
# Title: Sofia's Party Shoes  - Error fetching data from Google Books API.
# Title: The Beach Trip  - Error fetching data from Google Books API.
# Title: The Marigold Mess  - Error fetching data from Google Books API.
# Title: The Missing Mouse  - Error fetching data from Google Books API.
# Title: The Secret Recipe  - Error fetching data from Google Books API.
# Title: Jay's Gay Agenda - Error fetching data from Google Books API.
# Title: Amina's Voice  - Error fetching data from Google Books API.
# Title: Maya Angelou  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 1  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 3  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 4  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 5  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 6  - Error fetching data from Google Books API.
# Title: Blue Flag, Vol. 7  - Error fetching data from Google Books API.
# Title: Let's Talk About Love - Error fetching data from Google Books API.
# Title: The Fight  - Error fetching data from Google Books API.
# Title: Almost Perfect - Error fetching data from Google Books API.
# Title: Los colores de nuestra piel/The Colors of Us  - Error fetching data from Google Books API.
# Title: The Colors of Us/Los colores de nuestra piel - Error fetching data from Google Books API.
# Title: Milk and Honey - Error fetching data from Google Books API.
# Title: Not Light, but Fire - Error fetching data from Google Books API.
# Title: Life in Outer Space - Error fetching data from Google Books API.
# Title: Summer in the City of Roses - Error fetching data from Google Books API.
# Title: More Than We Can Tell - Error fetching data from Google Books API.
# Title: How to Be an Antiracist - Error fetching data from Google Books API.
# Title: Stamped from the Beginning - Error fetching data from Google Books API.
# Title: You - Error fetching data from Google Books API.
# Title: The Test  - Error fetching data from Google Books API.
# Title: Hello, I Lied - Error fetching data from Google Books API.
# Title: The Arabic Quilt - Error fetching data from Google Books API.
# Title: When They Call You a Terrorist  - Error fetching data from Google Books API.
# Title: Home of the Brave - Error fetching data from Google Books API.
# Title: Like the Moon Loves the Sky - Error fetching data from Google Books API.
# Title: Under My Hijab - Error fetching data from Google Books API.
# Title: Big Red Lollipop - Error fetching data from Google Books API.
# Title: The Love and Lies of Rukhsana Ali - Error fetching data from Google Books API.
# Title: Darius the Great Deserves Better  - Error fetching data from Google Books API.
# Title: Darius the Great Is Not Okay  - Error fetching data from Google Books API.
# Title: The Other Talk - Error fetching data from Google Books API.
# Title: They Called Me Red - Error fetching data from Google Books API.
# Title: My Princess Boy - Error fetching data from Google Books API.
# Title: Ask the Passengers - Error fetching data from Google Books API.
# Title: Everybody Sees the Ants - Error fetching data from Google Books API.
# Title: I See the Sun in Afghanistan - Error fetching data from Google Books API.
# Title: Elevation - Error fetching data from Google Books API.
# Title: All the Colors We Are - Error fetching data from Google Books API.
# Title: All the Colors We Are - Error fetching data from Google Books API.
# Title: Transgender Rights and Protections - Error fetching data from Google Books API.
# Title: Love Drugged - Error fetching data from Google Books API.
# Title: My Most Excellent Year - Error fetching data from Google Books API.
# Title: The Extraordinaries  - Error fetching data from Google Books API.
# Title: RIPPED-APART Understanding, Coping and Living with Gender Dysphoria - Book not found.
# Title: Jumping Off Swings  - Error fetching data from Google Books API.
# Title: Pearl - Error fetching data from Google Books API.
# Title: See You at Harry's - Error fetching data from Google Books API.
# Title: Gender Queer - Error fetching data from Google Books API.
# Title: Boy Girl Boy - Error fetching data from Google Books API.
# Title: Honestly Ben  - Error fetching data from Google Books API.
# Title: Openly Straight  - Error fetching data from Google Books API.
# Title: The Bridge - Error fetching data from Google Books API.
# Title: The Music of What Happens - Error fetching data from Google Books API.
# Title: The Porcupine of Truth - Error fetching data from Google Books API.
# Title: Same, Same But Different - Error fetching data from Google Books API.
# Title: Harvesting Hope - Error fetching data from Google Books API.
# Title: Sonia Sotomayor  - Error fetching data from Google Books API.
# Title: Starstruck - Error fetching data from Google Books API.
# Title: What Was the March on Washington?  - Error fetching data from Google Books API.
# Title: Hank's Big Day - Error fetching data from Google Books API.
# Title: Beyond Magenta - Error fetching data from Google Books API.
# Title: Lost and Found Cat  - Error fetching data from Google Books API.
# Title: The Purim Superhero - Error fetching data from Google Books API.
# Title: El color de la piel - Error fetching data from Google Books API.
# Title: Be Dazzled - Error fetching data from Google Books API.
# Title: Who Was Maya Angelou?  - Error fetching data from Google Books API.
# Title: Everything Leads to You - Error fetching data from Google Books API.
# Title: We Are Okay - Error fetching data from Google Books API.
# Title: You Know Me Well - Error fetching data from Google Books API.
# Title: The Dreamkeepers - Error fetching data from Google Books API.
# Title: ¡Vámonos! Let's Go! - Error fetching data from Google Books API.
# Title: A Little Piece of Ground - Error fetching data from Google Books API.
# Title: Date Violence  - Error fetching data from Google Books API.
# Title: Taking Responsibility - Error fetching data from Google Books API.
# Title: The Ultimate Guys' Body Book - Error fetching data from Google Books API.
# Title: 25 Women Who Dared to Go - Error fetching data from Google Books API.
# Title: Can I Touch Your Hair? Poems of Race, Mistakes, and Friendship - Error fetching data from Google Books API.
# Title: Autoboyography - Error fetching data from Google Books API.
# Title: Beautiful Bastard  - Error fetching data from Google Books API.
# Title: Running the Road to ABC - Error fetching data from Google Books API.
# Title: Trail of Crumbs - Error fetching data from Google Books API.
# Title: Rainbow Revolutions - Error fetching data from Google Books API.
# Title: All We Can Do Is Wait - Error fetching data from Google Books API.
# Title: Heavy - Error fetching data from Google Books API.
# Title: Drawn Together - Error fetching data from Google Books API.
# Title: My Book of Life by Angel - Error fetching data from Google Books API.
# Title: Absolute Brightness - Error fetching data from Google Books API.
# Title: I'll Be the One - Error fetching data from Google Books API.
# Title: Mindy Kim and the Big Pizza Challenge  - Error fetching data from Google Books API.
# Title: Mindy Kim and the Birthday Puppy  - Error fetching data from Google Books API.
# Title: Mindy Kim and the Fairy-Tale Wedding  - Error fetching data from Google Books API.
# Title: Mindy Kim and the Lunar New Year Parade  - Error fetching data from Google Books API.
# Title: Mindy Kim and the Trip to Korea  - Error fetching data from Google Books API.
# Title: Mindy Kim and the Yummy Seaweed Business  - Error fetching data from Google Books API.
# Title: Mindy Kim, Class President  - Error fetching data from Google Books API.
# Title: The Gentleman's Guide to Vice and Virtue  - Error fetching data from Google Books API.
# Title: The Lady's Guide to Petticoats and Piracy  - Error fetching data from Google Books API.
# Title: The Downstairs Girl - Error fetching data from Google Books API.
# Title: When Spring Comes to the DMZ - Error fetching data from Google Books API.
# Title: A Lesson in Vengeance - Error fetching data from Google Books API.
# Title: The Electric Heir  - Error fetching data from Google Books API.
# Title: The Fever King  - Error fetching data from Google Books API.
# Title: Rape On Campus - Error fetching data from Google Books API.
# Title: Gender Issues and Sexuality - Error fetching data from Google Books API.
# Title: Henry's Freedom Box - Error fetching data from Google Books API.
# ...
# Title: The Opposite of Innocent - Error fetching data from Google Books API.
# Title: What My Mother Doesn't Know  - Error fetching data from Google Books API.
# Title: At the Mountain's Base - Error fetching data from Google Books API.
# Title: We Are Grateful - Error fetching data from Google Books API.
# Title: Too Many Tamales - Error fetching data from Google Books API.
# Title: ¡Solo pregunta! - Error fetching data from Google Books API.
# Title: The Summer of Jordi Perez - Error fetching data from Google Books API.
# Title: The Summer of Jordi Perez  - Error fetching data from Google Books API.
# Title: Beast - Error fetching data from Google Books API.
# Title: Go Ask Alice - Error fetching data from Google Books API.
# Title: I Am Water - Error fetching data from Google Books API.
# Title: Maus 1 - Error fetching data from Google Books API.
# Title: Maus II - Error fetching data from Google Books API.
# Title: Freak Show - Error fetching data from Google Books API.
# Title: As Far As You'll Take Me - Error fetching data from Google Books API.
# Title: The Gravity of Us - Error fetching data from Google Books API.
# Title: The Gravity of Us  - Error fetching data from Google Books API.
# Title: 25 Women Who Ruled - Error fetching data from Google Books API.
# Title: Bright World  - Error fetching data from Google Books API.
# Title: Deogratias - Error fetching data from Google Books API.
# Title: The List of Things That Will Not Change - Error fetching data from Google Books API.
# Title: Whistling Vivaldi - Error fetching data from Google Books API.
# Title: The Watcher's Test  - Error fetching data from Google Books API.
# Title: The Art of Racing in the Rain - Error fetching data from Google Books API.
# Title: Of Mice and Men - Error fetching data from Google Books API.
# Title: Radiant Child - Error fetching data from Google Books API.
# Title: The Coldest Touch - Error fetching data from Google Books API.
# Title: These Witches Don't Burn  - Error fetching data from Google Books API.
# Title: The Exact Opposite of Okay  - Error fetching data from Google Books API.
# Title: Promoting Racial Literacy in Schools - Error fetching data from Google Books API.
# Title: The Fire Never Goes Out - Error fetching data from Google Books API.
# Title: Big Guy - Error fetching data from Google Books API.
# Title: En el bosque - Error fetching data from Google Books API.
# Title: Pride - Error fetching data from Google Books API.
# Title: Under Threat - Error fetching data from Google Books API.
# Title: Who Is Michelle Obama?  - Error fetching data from Google Books API.
# Title: Who Is Sonia Sotomayor?  - Error fetching data from Google Books API.
# Title: Who Was Marie Curie?  - Error fetching data from Google Books API.
# Title: Clean Getaway - Error fetching data from Google Books API.
# Title: Dear Martin - Error fetching data from Google Books API.
# Title: Odd One Out - Error fetching data from Google Books API.
# Title: A Bad Boy Can Be Good for a Girl - Error fetching data from Google Books API.
# Title: Born Out of Struggle - Error fetching data from Google Books API.
# Title: The Confessions of Nat Turner - Error fetching data from Google Books API.
# Title: It's Not Like It's a Secret - Error fetching data from Google Books API.
# Title: Mommy Sayang - Error fetching data from Google Books API.
# Title: The Dangerous Art of Blending In - Error fetching data from Google Books API.
# Title: Forbidden - Error fetching data from Google Books API.
# Title: Big Hair, Don't Care - Error fetching data from Google Books API.
# Title: Shining Legacy - Error fetching data from Google Books API.
# Title: They Called Us Enemy - Error fetching data from Google Books API.
# Title: As I Descended - Error fetching data from Google Books API.
# Title: Music from Another World - Error fetching data from Google Books API.
# Title: Pulp - Error fetching data from Google Books API.
# Title: The Love Curse of Melody McIntyre - Error fetching data from Google Books API.
# Title: Laura Dean Keeps Breaking Up with Me - Error fetching data from Google Books API.
# Title: This One Summer - Error fetching data from Google Books API.
# Title: Cilla Lee-Jenkins - Error fetching data from Google Books API.
# Title: Cilla Lee-Jenkins - Error fetching data from Google Books API.
# Title: Cilla Lee-Jenkins - Error fetching data from Google Books API.
# Title: I Love My Hair - Error fetching data from Google Books API.
# Title: Golden Boy - Error fetching data from Google Books API.
# Title: The Last Confession of Autumn Casterly - Error fetching data from Google Books API.
# Title: Can We Talk about Race? - Error fetching data from Google Books API.
# Title: Why Are All the Black Kids Sitting Together in the Cafeteria? - Error fetching data from Google Books API.
# Title: Henry Aaron's Dream - Error fetching data from Google Books API.
# Title: Sally and The Magical Sneeze - Error fetching data from Google Books API.
# Title: Me Myself & Him - Error fetching data from Google Books API.
# Title: Drama - Error fetching data from Google Books API.
# Title: The Hiding Place - Error fetching data from Google Books API.
# Title: Everything You Love Will Burn - Error fetching data from Google Books API.
# Title: Meg, Jo, Beth, and Amy - Error fetching data from Google Books API.
# Title: High Drama  - Error fetching data from Google Books API.
# Title: The Gender Quest Workbook - Error fetching data from Google Books API.
# Title: From the Stars in the Sky to the Fish in the Sea - Error fetching data from Google Books API.
# Title: Cemetery Boys - Error fetching data from Google Books API.
# Title: On the Come Up - Error fetching data from Google Books API.
# Title: The Hate U Give - Error fetching data from Google Books API.
# Title: #BlackLivesMatter - Error fetching data from Google Books API.
# Title: Your Name Is a Song - Error fetching data from Google Books API.
# Title: Blankets - Error fetching data from Google Books API.
# Title: Who Was Eleanor Roosevelt?  - Error fetching data from Google Books API.
# Title: Keena Ford and the Second Grade Mix Up  - Error fetching data from Google Books API.
# Title: Tarnished Are the Stars - Error fetching data from Google Books API.
# Title: My Whole Truth - Error fetching data from Google Books API.
# Title: After We Collided  - Error fetching data from Google Books API.
# Title: Remake  - Error fetching data from Google Books API.
# Title: Squad - Error fetching data from Google Books API.
# Title: Grandfather Tang's Story - Error fetching data from Google Books API.
# Title: Separate Is Never Equal - Error fetching data from Google Books API.
# Title: Soldier for Equality - Error fetching data from Google Books API.
# Title: The Princess and the Warrior - Error fetching data from Google Books API.
# Title: Abortion  - Error fetching data from Google Books API.
# Title: Fan Art - Error fetching data from Google Books API.
# Title: 7 Days at the Hot Corner - Error fetching data from Google Books API.
# Title: As Fast as Words Could Fly - Error fetching data from Google Books API.
# Title: Hachiko - Error fetching data from Google Books API.
# Title: A Day in the Life of Marlon Bundo - Error fetching data from Google Books API.
# Title: The Skin You Live In - Error fetching data from Google Books API.
# Title: Who I Was with Her - Error fetching data from Google Books API.
# Title: The Bracelet - Error fetching data from Google Books API.
# Title: A Storm Called Katrina - Error fetching data from Google Books API.
# Title: Dad, Jackie, and Me - Error fetching data from Google Books API.
# Title: #Hockey  - Error fetching data from Google Books API.
# Title: Sticks & Scones  - Error fetching data from Google Books API.
# Title: Beyond the Gender Binary - Error fetching data from Google Books API.
# Title: Hello Now - Error fetching data from Google Books API.
# Title: Subtractive Schooling - Error fetching data from Google Books API.
# Title: Peanut Goes for the Gold - Error fetching data from Google Books API.
# Title: Date Me, Bryson Keller - Error fetching data from Google Books API.
# Title: Totem Tale - Error fetching data from Google Books API.
# Title: Alison, Who Went Away - Error fetching data from Google Books API.
# Title: Crier's War  - Error fetching data from Google Books API.
# Title: Iron Heart  - Error fetching data from Google Books API.
# Title: Saga, Volume 1  - Error fetching data from Google Books API.
# Title: Y - Error fetching data from Google Books API.
# Title: Looking for Bongo - Error fetching data from Google Books API.
# Title: Kiss Number 8 - Error fetching data from Google Books API.
# Title: Faith Ringgold  - Error fetching data from Google Books API.
# Title: I Am Human - Error fetching data from Google Books API.
# Title: And She Was - Error fetching data from Google Books API.
# Title: Follow Your Arrow - Error fetching data from Google Books API.
# Title: This Golden Flame - Error fetching data from Google Books API.
# Title: Fifteen Hundred Miles from the Sun - Error fetching data from Google Books API.
# Title: The Grief Keeper - Error fetching data from Google Books API.
# Title: Black and White - Error fetching data from Google Books API.
# Title: Crossing Lines - Error fetching data from Google Books API.
# Title: Gossip Girl - Error fetching data from Google Books API.
# Title: Slaughterhouse-Five - Error fetching data from Google Books API.
# Title: Condoleezza Rice - Error fetching data from Google Books API.
# Title: Dreadnought  - Error fetching data from Google Books API.
# Title: On a Sunbeam  - Error fetching data from Google Books API.
# Title: Spinning - Error fetching data from Google Books API.
# Title: Beyond Theory - Error fetching data from Google Books API.
# Title: Our Favorite African Adrinkra Symbols - Error fetching data from Google Books API.
# Title: The Color Purple - Error fetching data from Google Books API.
# Title: Dishes - Error fetching data from Google Books API.
# Title: Ada Byron Lovelace and the Thinking Machine - Error fetching data from Google Books API.
# Title: Grace Hopper - Error fetching data from Google Books API.
# Title: The Glass Castle - Error fetching data from Google Books API.
# Title: If We Were Us - Error fetching data from Google Books API.
# Title: Introducing Teddy - Error fetching data from Google Books API.
# Title: Empty - Error fetching data from Google Books API.
# Title: The Prince and the Dressmaker - Error fetching data from Google Books API.
# Title: Salvage the Bones  - Error fetching data from Google Books API.
# Title: Aesop Lake - Error fetching data from Google Books API.
# Title: Other Words for Home - Error fetching data from Google Books API.
# Title: The Shape of Thunder - Error fetching data from Google Books API.
# Title: Ghost Wood Song - Error fetching data from Google Books API.
# Title: Harlem's Little Blackbird - Error fetching data from Google Books API.
# Title: Piecing Me Together - Error fetching data from Google Books API.
# Title: Before John Was a Jazz Giant - Error fetching data from Google Books API.
# Title: Freedom in Congo Square - Error fetching data from Google Books API.
# Title: Gordon Parks - Error fetching data from Google Books API.
# Title: Suicide Notes From Beautiful Girls - Error fetching data from Google Books API.
# Title: The Book of Essie - Error fetching data from Google Books API.
# Title: Luciana  - Error fetching data from Google Books API.
# Title: Yoko  - Error fetching data from Google Books API.
# Title: Whistle Me Home - Error fetching data from Google Books API.
# Title: Saving Ruby King - Error fetching data from Google Books API.
# Title: Afterworlds  - Error fetching data from Google Books API.
# Title: Uglies  - Error fetching data from Google Books API.
# Title: On the Come Up - Error fetching data from Google Books API.
# Title: Molly of Denali - Error fetching data from Google Books API.
# Title: Highly Illogical Behavior - Error fetching data from Google Books API.
# Title: A Certain Slant of Light - Error fetching data from Google Books API.
# Title: And I Darken  - Error fetching data from Google Books API.
# Title: The Dark Descent of Elizabeth Frankenstein - Error fetching data from Google Books API.
# Title: Considering Hate - Error fetching data from Google Books API.
# Title: Night - Error fetching data from Google Books API.
# Title: Playing a Part - Error fetching data from Google Books API.
# Title: Caste - Error fetching data from Google Books API.
# Title: Pink - Error fetching data from Google Books API.
# Title: Because - Error fetching data from Google Books API.
# Title: Daddy's Roommate - Error fetching data from Google Books API.
# Title: The Boy in the Dress - Error fetching data from Google Books API.
# Title: Four Feet, Two Sandals - Error fetching data from Google Books API.
# Title: The Art of Being Normal - Error fetching data from Google Books API.
# Title: Fences - Error fetching data from Google Books API.
# Title: Young Gifted and Black - Error fetching data from Google Books API.
# Title: What Is Black Lives Matter?  - Error fetching data from Google Books API.
# Title: We Now Return to Regular Life - Error fetching data from Google Books API.
# Title: What They Always Tell Us - Error fetching data from Google Books API.
# Title: No Way, They Were Gay? - Error fetching data from Google Books API.
# Title: Gender Identity - Error fetching data from Google Books API.
# Title: Roberto Clemente - Error fetching data from Google Books API.
# Title: Sonia Sotomayor - Error fetching data from Google Books API.
# Title: The Summer of Everything - Error fetching data from Google Books API.
# Title: Parrotfish - Error fetching data from Google Books API.
# Title: Saturdays with Hitchcock - Error fetching data from Google Books API.
# Title: Doing It! - Error fetching data from Google Books API.
# Title: My Name Is Sally Little Song - Error fetching data from Google Books API.
# Title: Identifying as Transgender - Error fetching data from Google Books API.
# Title: Before the Ever After - Error fetching data from Google Books API.
# Title: Beneath a Meth Moon - Error fetching data from Google Books API.
# Title: Brown Girl Dreaming - Error fetching data from Google Books API.
# Title: Each Kindness - Error fetching data from Google Books API.
# Title: El Día En Que Descubres Quién Eres - Error fetching data from Google Books API.
# Title: Red at the Bone - Error fetching data from Google Books API.
# Title: The Day You Begin - Error fetching data from Google Books API.
# Title: The Dear One - Error fetching data from Google Books API.
# Title: The House You Pass on the Way - Error fetching data from Google Books API.
# Title: The Other Side - Error fetching data from Google Books API.
# Title: Understanding Sexuality - Error fetching data from Google Books API.
# Title: Life at School and in the Community  - Error fetching data from Google Books API.
# Title: Noah Chases the Wind - Error fetching data from Google Books API.
# Title: Putting Makeup on the Fat Boy - Error fetching data from Google Books API.
# Title: Always my Dad - Error fetching data from Google Books API.
# Title: Orphea Proud - Error fetching data from Google Books API.
# Title: American Born Chinese - Error fetching data from Google Books API.
# Title: Front Desk  - Error fetching data from Google Books API.
# Title: Parachutes - Error fetching data from Google Books API.
# Title: Dragonwings - Error fetching data from Google Books API.
# Title: Coolies - Error fetching data from Google Books API.
# Title: Encounter - Error fetching data from Google Books API.
# Title: One Hot Second - Error fetching data from Google Books API.
# Title: Malala - Error fetching data from Google Books API.
# Title: Malala's Magic Pencil - Error fetching data from Google Books API.
# Title: Witchlight - Error fetching data from Google Books API.
# Title: Who Was Sojourner Truth?  - Error fetching data from Google Books API.
# Title: The Garden of My Imaan - Error fetching data from Google Books API.
# Title: Read the World - Error fetching data from Google Books API.
# Title: American Street - Error fetching data from Google Books API.
# Title: Black Enough - Error fetching data from Google Books API.
# Title: Grandpa Cacao - Error fetching data from Google Books API.

# %%
banned_df.head(50)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                         author  \
# 0       Àbíké-Íyímídé, Faridah
# 1           Acevedo, Elizabeth
# 2           Acevedo, Elizabeth
# 6                Aciman, André
# 7                  Acito, Marc
# 8               Ada, Alma Flor
# 9                 Addasi, Maha
# 10               Adeyemi, Tomi
# 11               Adeyoha, Koja
# 12   Adichie, Chimamanda Ngozi
# 13               Adler, Dahlia
# 14            Agell, Charlotte
# 15               Ahmadi, Arvin
# 17                 Ahmed, Roda
# 18               Ahmed, Samira
# 20              Ahmed, Sara K.
# 22           Albertalli, Becky
# 23           Albertalli, Becky
# 24           Albertalli, Becky
# 26           Albertalli, Becky
# 27           Albertalli, Becky
# 30           Albertalli, Becky
# 33           Albertalli, Becky
# 36              Aleman, Daniel
# 37            Alexander, Kwame
# 38         Alexander, Michelle
# 41             Alexie, Sherman
# 57             Alexie, Sherman
# 58             Alger, Cristina
# 59                Alko, Selina
# 60             Allende, Isabel
# 61        Alley, Kristy Dallas
# 62            Allison, Anthony
# 63         Allman, John Robert
# 64        Altman, Linda Jacobs
# 66       Amnesty International
# 67              Anaya, Rudolfo
# 68                  Ancrum, K.
# 69        Anders, Charlie Jane
# 70            Anderson, Airlie
# 71             Anderson, Carol
# 72      Anderson, Laurie Halse
# 75      Anderson, Laurie Halse
# 81             Anderson, M. T.
# 82               Andrews, Arin
# 83              Andrews, Jesse
# 97              Andrews, Jesse
# 100              Andrews, Troy
# 101              Andrews, Troy
# 102              Angelou, Maya
#
#                                                title  \
# 0                                      Ace of Spades
# 1                                 Clap When You Land
# 2                                         The Poet X
# 6                              Call Me By Your Name
# 7                             How I Paid for College
# 8                            My Name Is María Isabel
# 9                                       Time to Pray
# 10                       Children of Blood and Bone
# 11                                      47,000 Beads
# 12                              Half of a Yellow Sun
# 13                               Cool for the Summer
# 14     The Accidental Adventures of India McAllister
# 15                                How It All Blew Up
# 17                               Mae Among the Stars
# 18                        Love, Hate & Other Filters
# 20                                  Being the Change
# 22                                      Here's to Us
# 23                                   Kate in Waiting
# 24                              Leah on the Offbeat
# 26                                   Love, Creekwood
# 27                Simon vs. the Homo Sapiens Agenda
# 30                         The Upside of Unrequited
# 33                                  What If It's Us
# 36                                       Indivisible
# 37                                    The Undefeated
# 38                                  The New Jim Crow
# 41   The Absolutely True Diary of a Part-Time Indian
# 57                                   Thunder Boy Jr.
# 58                                    Girls Like Us
# 59                               The Case for Loving
# 60                          The House of the Spirits
# 61                           The Ballad of Ami Miles
# 62                                 Hear These Voices
# 63                                    A is for Audra
# 64                                         Bioethics
# 66                              We Are All Born Free
# 67                                  Bless Me, Ultima
# 68                           The Weight of the Stars
# 69                     Victories Greater Than Death
# 70                                           Neither
# 71                                        White Rage
# 72                                             Shout
# 75                                             Speak
# 81                                              Feed
# 82                            Some Assembly Required
# 83                    Me and Earl and the Dying Girl
# 97                                        The Haters
# 100                               The 5 O'Clock Band
# 101                                  Trombone Shorty
# 102                                 And Still I Rise
#
#                                            description published_date
# 0    Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1    In a novel-in-verse that brims with grief and ...     2020-05-05
# 2    A National Book Award Longlist title! Fans of ...     2019-03-19
# 6                                                  NaN            NaN
# 7                                                  NaN            NaN
# 8                                                  NaN            NaN
# 9                                                  NaN            NaN
# 10                                                 NaN            NaN
# 11   When Peyton doesn't want to wear a dress or da...           2017
# 12   From the award-winning, bestselling author of ...     2007-09-04
# 13                                                 NaN            NaN
# 14   Fourth grade is a year of changes, challenges,...     2010-06-22
# 15   Simon vs. the Homo Sapiens Agenda goes to Ital...     2021-09-28
# 17   An Amazon Best Book of the Month A beautiful p...     2018-01-09
# 18                                                 NaN            NaN
# 20   "This book is about spending time learning abo...           2018
# 22                                                 NaN            NaN
# 23                                                 NaN            NaN
# 24                                                 NaN            NaN
# 26                                                 NaN            NaN
# 27                                                 NaN            NaN
# 30                                                 NaN            NaN
# 33                                                 NaN            NaN
# 36   A timely, moving debut novel about a teen's ef...     2021-05-04
# 37                                                 NaN            NaN
# 38   Named one of the most important nonfiction boo...     2020-01-07
# 41                                                 NaN            NaN
# 57                                                 NaN            NaN
# 58                                                 NaN            NaN
# 59                 The fight for interracial marriage.           2015
# 60                                                 NaN            NaN
# 61                                                 NaN            NaN
# 62   Presents case studies of teenagers living with...           1999
# 63                                                 NaN            NaN
# 64                                                 NaN            NaN
# 66   The Universal Declaration of Human Rights was ...     2016-05-03
# 67   From "one of the nation's foremost Chicano lit...     2012-06-01
# 68   A vivid, evocative YA lesbian romance about ho...     2019-03-19
# 69                                                 NaN            NaN
# 70   In this colorful and touching story that celeb...     2018-03-06
# 71                                                 NaN            NaN
# 72                                                 NaN            NaN
# 75                                                 NaN            NaN
# 81                                                 NaN            NaN
# 82                                                 NaN            NaN
# 83                                                 NaN            NaN
# 97   From Jesse Andrews, author of the New York Tim...     2016-04-05
# 100  This companion title to Trombone Shorty—Caldec...     2020-11-10
# 101                                                NaN            NaN
# 102  Maya Angelou’s unforgettable collection of poe...     2011-08-17

# %%
banned_df['description']
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0       Gossip Girl meets Get Out in Ace of Spades, a ...
# 1       In a novel-in-verse that brims with grief and ...
# 2       A National Book Award Longlist title! Fans of ...
# 6                                                     NaN
# 7                                                     NaN
#                               ...
# 2527                                                  NaN
# 2528                                                  NaN
# 2529                                                  NaN
# 2530                                                  NaN
# 2531                                                  NaN
# Name: description, Length: 1656, dtype: object

# %%
banned_df.to_csv('banned_book_descriptions.csv', index=False)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df = pd.read_csv('banned_book_descriptions.csv')
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655                                                NaN            NaN
#
# [1656 rows x 4 columns]

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author               0
# title                0
# description       1138
# published_date    1132
# dtype: int64

# %%
# we have about 500 descriptions, let's start playing around with this

# %% [markdown]
# We've reached our API limit; we can pull more requests another day.

# %% [markdown]
# ## Iterate more requests
#
# Now that it's another day, we can try pulling more requests.

# %%
banned_df = pd.read_csv('banned_book_descriptions.csv')
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author               0
# title                0
# description       1138
# published_date    1132
# dtype: int64

# %%
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4     A deliciously funny romp of a novel about one ...     2005-08-02
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655  This beautifully illustrated story connects pa...     2019-05-21
#
# [1656 rows x 4 columns]

# %%
import math

df_len = len(banned_df)
import time
batch_size = 50

for i in range(0, df_len, batch_size):
    for j in range(i, min(i+batch_size, df_len)):
        check_value = banned_df.iloc[j]['description']
        try:
          if math.isnan(check_value):
            title = banned_df.iloc[j]['title']
            author = banned_df.iloc[j]['author']
            paste_book_details(title, author)
        except TypeError:
          pass
    time.sleep(120)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author              0
# title               0
# description       620
# published_date    620
# dtype: int64

# %%
banned_df.to_csv('banned_book_descriptions.csv', index=False)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
banned_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                       author                   title  \
# 0     Àbíké-Íyímídé, Faridah           Ace of Spades
# 1         Acevedo, Elizabeth      Clap When You Land
# 2         Acevedo, Elizabeth              The Poet X
# 3              Aciman, André   Call Me By Your Name
# 4                Acito, Marc  How I Paid for College
# ...                      ...                     ...
# 1651            Zia, Farhana  The Garden of My Imaan
# 1652         Ziemke, Kristin          Read the World
# 1653              Zoboi, Ibi         American Street
# 1654              Zoboi, Ibi            Black Enough
# 1655        Zunon, Elizabeth           Grandpa Cacao
#
#                                             description published_date
# 0     Gossip Girl meets Get Out in Ace of Spades, a ...     2021-06-01
# 1     In a novel-in-verse that brims with grief and ...     2020-05-05
# 2     A National Book Award Longlist title! Fans of ...     2019-03-19
# 3                                                   NaN            NaN
# 4     A deliciously funny romp of a novel about one ...     2005-08-02
# ...                                                 ...            ...
# 1651                                                NaN            NaN
# 1652                                                NaN            NaN
# 1653                                                NaN            NaN
# 1654                                                NaN            NaN
# 1655  This beautifully illustrated story connects pa...     2019-05-21
#
# [1656 rows x 4 columns]

# %%
banned_df.isna().sum()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# author              0
# title               0
# description       620
# published_date    620
# dtype: int64

# %%
# we have over 1000 descriptions!
